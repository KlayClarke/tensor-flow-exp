# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line Chart

# %%
# create one dimensional array with 1000 evenly spaced pointer between 0 and 20

x = np.linspace(0,20,1000)

# %%
# generate fake data for Y Axis (this case would gen a sine wav)

y = np.sin(x) + .2 * x

# %%
# plot data

plt.plot(x,y)

# %%
# label axes

plt.plot(x,y)
plt.xlabel("input")
plt.ylabel("output")
plt.title("random plot");

# %% [markdown]
# ## Scatterplot

# %%
# 100 data points with dimensionality 2

x = np.random.randn(100,2)

# %%
# to create scatter plot

plt.scatter(x[:,0], x[:,1])

# %%
# create scatter plot with 200 data points

x = np.random.randn(200,2)

# %%
# center first half of data points at 3,3

x[:50] += 3

# %%
# create array of zeros the size of 200

y = np.zeros(200)

# %%
# set first half of these to 1

y[:50] = 1

# %%
# c variable allows you to color the plot

plt.scatter(x[:,0],x[:,1], c=y)

# %% [markdown]
# ## Histogram

# %%
# create 10000 random numbers (sample from standard normal distribution)

x = np.random.randn(10000)

# %%
x
# Out:
# array([-0.97773945,  0.01365264, -0.04224006, ...,  0.79696626,
#         0.36785384, -1.19175908])

# %%
# plot histogram -- notice the bell curve (confirms that our data comes from standard normal)

plt.hist(x)
# Out:
# (array([3.000e+00, 3.900e+01, 3.420e+02, 1.426e+03, 2.975e+03, 3.108e+03,
#         1.678e+03, 3.820e+02, 4.300e+01, 4.000e+00]),
#  array([-4.34484037, -3.48613436, -2.62742836, -1.76872235, -0.91001634,
#         -0.05131034,  0.80739567,  1.66610168,  2.52480768,  3.38351369,
#          4.2422197 ]),
#  <BarContainer object of 10 artists>)

# %%
# edit number of bars using bins arg

plt.hist(x, bins=50)
# Out:
# (array([  2.,   0.,   0.,   0.,   1.,   1.,   5.,   7.,  11.,  15.,  34.,
#          43.,  74.,  84., 107., 162., 214., 277., 354., 419., 479., 566.,
#         606., 636., 688., 681., 693., 622., 557., 555., 483., 398., 330.,
#         244., 223., 141., 103.,  58.,  50.,  30.,  15.,  12.,   8.,   6.,
#           2.,   2.,   0.,   1.,   0.,   1.]),
#  array([-4.34484037, -4.17309917, -4.00135797, -3.82961677, -3.65787556,
#         -3.48613436, -3.31439316, -3.14265196, -2.97091076, -2.79916956,
#         -2.62742836, -2.45568716, -2.28394595, -2.11220475, -1.94046355,
#         -1.76872235, -1.59698115, -1.42523995, -1.25349875, -1.08175754,
#         -0.91001634, -0.73827514, -0.56653394, -0.39479274, -0.22305154,
#         -0.05131034,  0.12043087,  0.29217207,  0.46391327,  0.63565447,
#          0.80739567,  0.97913687,  1.15087807,  1.32261927,  1.49436048,
#          1.66610168,  1.83784288,  2.00958408,  2.18132528,  2.35306648,
#          2.52480768,  2.69654889,  2.86829009,  3.04003129,  3.21177249,
#          3.38351369,  3.55525489,  3.72699609,  3.8987373 ,  4.0704785 ,
#          4.2422197 ]),
#  <BarContainer object of 50 artists>)

# %%
# create 10000 random numbers from uniform distribution

x = np.random.random(10000)

# %%
# plot histogram -- notice the uniformity 

plt.hist(x, bins=50)
# Out:
# (array([206., 199., 211., 198., 208., 191., 180., 172., 165., 192., 167.,
#         214., 204., 215., 204., 165., 201., 193., 223., 209., 215., 174.,
#         202., 206., 189., 206., 200., 183., 214., 241., 195., 220., 206.,
#         199., 173., 213., 224., 206., 214., 222., 175., 210., 194., 214.,
#         197., 201., 190., 222., 199., 179.]),
#  array([5.35711098e-05, 2.00508883e-02, 4.00482055e-02, 6.00455228e-02,
#         8.00428400e-02, 1.00040157e-01, 1.20037474e-01, 1.40034792e-01,
#         1.60032109e-01, 1.80029426e-01, 2.00026743e-01, 2.20024061e-01,
#         2.40021378e-01, 2.60018695e-01, 2.80016012e-01, 3.00013329e-01,
#         3.20010647e-01, 3.40007964e-01, 3.60005281e-01, 3.80002598e-01,
#         3.99999915e-01, 4.19997233e-01, 4.39994550e-01, 4.59991867e-01,
#         4.79989184e-01, 4.99986502e-01, 5.19983819e-01, 5.39981136e-01,
#         5.59978453e-01, 5.79975770e-01, 5.99973088e-01, 6.19970405e-01,
#         6.39967722e-01, 6.59965039e-01, 6.79962357e-01, 6.99959674e-01,
#         7.19956991e-01, 7.39954308e-01, 7.59951625e-01, 7.79948943e-01,
#         7.99946260e-01, 8.19943577e-01, 8.39940894e-01, 8.59938211e-01,
#         8.79935529e-01, 8.99932846e-01, 9.19930163e-01, 9.39927480e-01,
#         9.59924798e-01, 9.79922115e-01, 9.99919432e-01]),
#  <BarContainer object of 50 artists>)

# %%
# !wget https://i.imgur.com/XQmklsI.jpeg
# Out:
# zsh:1: command not found: wget

# %%
from PIL import Image

# %%
# open image

im = Image.open('XQmklsI.jpeg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/rp/zmp7c3td5qv1nc21yy743b4r0000gn/T/ipykernel_9246/2951441169.py in <module>
#       1 # open image
#       2
# ----> 3 im = Image.open('XQmklsI.jpeg')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'XQmklsI.jpeg'

# %%
# file type

type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
# to convert im to np array

arr = np.array(im)

# %%
arr
# Out:
# array([[[ 73,  83,  95],
#         [ 72,  82,  94],
#         [ 71,  81,  93],
#         ...,
#         [244, 249, 243],
#         [244, 249, 243],
#         [244, 249, 243]],
#
#        [[ 72,  82,  94],
#         [ 72,  82,  94],
#         [ 72,  82,  94],
#         ...,
#         [244, 249, 243],
#         [244, 249, 243],
#         [244, 249, 243]],
#
#        [[ 71,  79,  92],
#         [ 72,  80,  93],
#         [ 74,  82,  95],
#         ...,
#         [244, 249, 243],
#         [244, 249, 243],
#         [244, 249, 243]],
#
#        ...,
#
#        [[ 43,  56,  39],
#         [ 41,  54,  37],
#         [ 41,  54,  37],
#         ...,
#         [ 92, 103, 107],
#         [ 91, 102, 106],
#         [ 90, 101, 105]],
#
#        [[ 41,  54,  37],
#         [ 41,  54,  37],
#         [ 40,  53,  36],
#         ...,
#         [ 92, 103, 107],
#         [ 92, 103, 107],
#         [ 91, 102, 106]],
#
#        [[ 39,  52,  35],
#         [ 43,  56,  39],
#         [ 44,  57,  40],
#         ...,
#         [ 92, 103, 107],
#         [ 91, 102, 106],
#         [ 91, 102, 106]]], dtype=uint8)

# %%
# shape of im / array

arr.shape
# Out:
# (2160, 3840, 3)

# %%
# 2160 == h, 3840 == w, 3 == rgb (? storage of each pixel color)

# %%
# to plot image

plt.imshow(arr)

# %%
# also works with original image

plt.imshow(im)

# %%
# to remove color from image 

gray = arr.mean(axis=2)

# %%
gray.shape
# Out:
# (2160, 3840)

# %%
plt.imshow(gray, cmap="gray")

# %% [markdown]
# ## Plot Generalized XOR
# get random data
# scatter
# generate xor plot
# color by quadrant
# make sure axes range from -1 to 1

# %%
xs = np.random.uniform(low=-1, high=1, size=(2000,2))

# %%
xs
# Out:
# array([[ 0.84299736,  0.84862633],
#        [ 0.25285404,  0.23815076],
#        [ 0.99681542,  0.69168335],
#        ...,
#        [-0.06667425,  0.57155938],
#        [-0.93389002,  0.02630443],
#        [-0.19076964,  0.39431411]])

# %%
y = np.bitwise_xor(np.sign(x[:,0]).astype(int))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-3e561abe2a2d> in <module>()
# ----> 1 y = np.bitwise_xor(np.sign(x[:,0]).astype(int))
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
plt.scatter(xs[:,0],xs[:,1], c=y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-431f31a4687f> in <module>()
# ----> 1 plt.scatter(xs[:,0],xs[:,1], c=y)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4401             self._parse_scatter_color_args(
#    4402                 c, edgecolors, kwargs, x.size,
# -> 4403                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4404
#    4405         if plotnonfinite and colors is None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4237         if not c_is_mapped:
#    4238             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4239                 colors = mcolors.to_rgba_array(c)
#    4240             except ValueError:
#    4241                 if not valid_shape:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     335             return result
#     336
# --> 337     if len(c) == 0:
#     338         return np.zeros((0, 4), float)
#     339     else:
#
# TypeError: len() of unsized object
